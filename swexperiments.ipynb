# %%
from moves import *
from itertools import product
from typing import Callable
import numpy as np
import matplotlib.pyplot as plt

# %%
def get_loc(location, action, move_dic):
    try:
        return move_dic[tuple([int(location), int(action)])]
    except KeyError:
        return location


def get_reward(player, location, action):
    if player == 1 and location == 7 and action == 3:
        return 100
    if player == 0 and location == 11 and action ==3:
        return 100
    return 1

# %%
def reward_nash(us):
    return np.sum(np.log(us))

def reward_util(us):
    return np.sum(us)

def reward_egal(us):
    return min(us)

def reward_eite(us):
    return max(us)

def value_iteration(num_states: int, num_actions: int, loc_fn: Callable,
                    get_reward: Callable, move_dic: dict, t1: list, t2: list, gamma: float, swf: Callable):
    # Set some paramaters and initial values
    gamma = gamma
    u1 = 1
    u2 = 1
    values = {(i, j): 0 for i in range(num_states) for j in range(num_states)}
    best_actions = {(i, j): None for i in range(num_states) for j in range(num_states)}
    converged = False

    while not converged:
        # Convergence is defined for when the max shift in our state value is less than 1e-4
        converged = True
        for s in values:
            best_value = -np.inf
            best_move = None
            p1 = s[0]
            p2 = s[1]
            for i, move in enumerate(product(list(range(num_actions)), list(range(num_actions)))):
                # Iterate through all moves and find the best one
                a1 = move[0]
                a2 = move[1]
                p1n = loc_fn(p1, a1, move_dic)
                p2n = loc_fn(p2, a2, move_dic)
                r1 = get_reward(0, p1, a1)
                r2 = get_reward(1, p2, a2)
                if p1n == p2n or (p1n == p2 and p2n == p1):
                    r1 = 1
                    r2 = 1
                    p1n = p1
                    p2n = p2
                # Plot global welfare (cumulative discounted utility functions) v(state) = sum(r_t*gamma^t
                u1n = u1 + gamma*r1
                u2n = u2 + gamma*r2
                # Wasn't sure whether to use augmented or normal MDP here. If normal MDP is used, we have to give non-zero reward
                # reward = np.sum(np.log([u1n, u2n])) - np.sum(np.log([u1, u2]))
                # u1 = 1 + 1*gamma + 1*gamma^2 + 1*gamma^3 + 100*gamma^4
                # u1, u2, welfare
                reward = swf([r1, r2])
                value = reward + gamma*values[(p1n, p2n)]
                if p1 in t1 or p2 in t2:
                    # Terminal states have value 0 by definition
                    value = 0
                if value > best_value:
                    best_value = value
                    best_move = move
            if abs(best_value - values[s]) > 1e-4:
                converged = False
            values[s] = best_value
            best_actions[s] = best_move
    return values, best_actions

# %%
def get_path(best_actions, loc_fn, move_dic, p1, p2, t1, t2, gamma):
    s = (p1, p2)
    i = 0
    reward1 = []
    reward2 = []
    while s[0] not in t1 and s[1] not in  t2:
        a1, a2 = best_actions[s]
        r1 = get_reward(0, p1, a1)
        r2 = get_reward(1, p2, a2)
        p1n = loc_fn(p1, a1, move_dic)
        p2n = loc_fn(p2, a2, move_dic)
        sn = (p1n, p2n)
        # print(f'I started at {s}, took action {a1, a2} and moved to {sn} ')
        s = sn
        p1 = p1n
        p2 = p2n
        reward1.append(r1*gamma**i)
        reward2.append(r2*gamma**i)
        i += 1
    return s, i, reward1, reward2

# %%
opt = 0
actuals_nash = []
bests_nash = []

swf = reward_nash
for g in range(98):
    g = (g + 1)/100
    best_value = [g**(k) for k in range(6)]
    best_value.append(100*g**6)
    best_value = sum(best_value)
    best = swf([best_value, best_value])

    values, best_actions = value_iteration(14, 4, get_loc, get_reward, moves1, t1=[3], t2=[1], gamma=g, swf=swf)
    terminal, num_steps, r1, r2 = get_path(best_actions, get_loc, moves1, 7, 11, [3], [1], g)
    actual1 = sum(r1)
    actual2 = sum(r2)
    actual = swf([actual1, actual2])
    strategy = 1
    if terminal == (3, 1):
        strategy = 2

    best = max(actual, best)
    actuals_nash.append(actual)
    bests_nash.append(best)

    print(f'I am running strategy {strategy} for {g} with value {values[(7, 11)]}, {actual - best}')
# Out:
# I am running strategy 1 for 0.01 with value 4.6051701859880923e-08, 0.0
# I am running strategy 1 for 0.02 with value 7.368272297580948e-07, 0.0
# I am running strategy 1 for 0.03 with value 3.7301878506503532e-06, 0.0
# I am running strategy 1 for 0.04 with value 1.1789235676129516e-05, 0.0
# I am running strategy 1 for 0.05 with value 2.878231366242558e-05, 0.0
# I am running strategy 1 for 0.06 with value 5.968300561040565e-05, 0.0
# I am running strategy 1 for 0.07 with value 0.00011057013616557413, 0.0
# I am running strategy 1 for 0.08 with value 0.00018862777081807226, 0.0
# I am running strategy 1 for 0.09 with value 0.00030214521590267863, 0.0
# I am running strategy 1 for 0.1 with value 0.00046051701859880926, 0.0
# I am running strategy 1 for 0.11 with value 0.0006742429669305165, 0.0
# I am running strategy 1 for 0.12 with value 0.0009549280897664904, 0.0
# I am running strategy 1 for 0.13 with value 0.0013152826568200594, 0.0
# I am running strategy 1 for 0.14 with value 0.001769122178649186, 0.0
# I am running strategy 1 for 0.15 with value 0.002331367406656471, 0.0
# I am running strategy 1 for 0.16 with value 0.003018044333089156, 0.0
# I am running strategy 1 for 0.17 with value 0.003846284191039115, 0.0
# I am running strategy 1 for 0.18 with value 0.004834323454442858, 0.0
# I am running strategy 1 for 0.19 with value 0.006001503838081542, 0.0
# I am running strategy 1 for 0.2 with value 0.007368272297580948, 0.0
# I am running strategy 1 for 0.21 with value 0.0089561810294115, 0.0
# I am running strategy 1 for 0.22 with value 0.010787887470888264, 0.0
# I am running strategy 1 for 0.23 with value 0.012887154300170936, 0.0
# I am running strategy 1 for 0.24 with value 0.015278849436263847, 0.0
# I am running strategy 1 for 0.25 with value 0.017988946039015984, 0.0
# I am running strategy 1 for 0.26 with value 0.02104452250912095, 0.0
# I am running strategy 1 for 0.27 with value 0.02447376248811698, 0.0
# I am running strategy 1 for 0.28 with value 0.028305954858386977, 0.0
# I am running strategy 1 for 0.29 with value 0.03257149374315843, 0.0
# I am running strategy 1 for 0.3 with value 0.03730187850650354, 0.0
# I am running strategy 1 for 0.31 with value 0.04252971375333908, 0.0
# I am running strategy 1 for 0.32 with value 0.0482887093294265, 0.0
# I am running strategy 1 for 0.33 with value 0.054613680321371844, 0.0
# I am running strategy 1 for 0.34 with value 0.06154054705662584, 0.0
# I am running strategy 1 for 0.35 with value 0.06910633510348378, 0.0
# I am running strategy 1 for 0.36 with value 0.07734917527108573, 0.0
# I am running strategy 1 for 0.37 with value 0.08630830360941627, 0.0
# I am running strategy 1 for 0.38 with value 0.09602406140930467, 0.0
# I am running strategy 2 for 0.83 with value 3.011232120069467, 0.0
# I am running strategy 2 for 0.84 with value 3.23557444318861, 0.0
# I am running strategy 2 for 0.85 with value 3.4736754100321994, 0.0
# I am running strategy 2 for 0.86 with value 3.7262019389518817, 0.0
# I am running strategy 2 for 0.87 with value 3.993844905499852, 0.0
# I am running strategy 2 for 0.88 with value 4.277319709417406, 0.0
# I am running strategy 2 for 0.89 with value 4.5773668482549414, 0.0
# I am running strategy 2 for 0.9 with value 4.894752497623395, 0.0
# I am running strategy 2 for 0.91 with value 5.230269098077142, 0.0
# I am running strategy 2 for 0.92 with value 5.584735948628317, 0.0
# I am running strategy 2 for 0.93 with value 5.958999806892605, 0.0
# I am running strategy 2 for 0.94 with value 6.353935495866445, 0.0
# I am running strategy 2 for 0.95 with value 6.7704465173357375, 0.0
# I am running strategy 2 for 0.96 with value 7.209465671915909, 0.0
# I am running strategy 2 for 0.97 with value 7.671955685723512, 0.0
# I am running strategy 2 for 0.98 with value 8.158909843679199, 0.0

# %%
fig = plt.figure()
x = np.arange(.01, .99, .01)
ax = fig.add_subplot()
ax.plot(x, actuals_nash, label='Myopic', interpolate=True)
ax.plot(x, bests_nash, '--', label='Global')
x_ticks = [(a + 1)/100 for a in range(99)]
x = range(99)
plt.xlabel('gamma')
plt.ylabel('Log Social Welfare')
# [l.set_visible(False) for (i,l) in enumerate(plt.xaxis.get_ticklabels()) if i % 10 != 0]

plt.legend()
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [49], in <cell line: 4>()
#       2 x = np.arange(.01, .99, .01)
#       3 ax = fig.add_subplot()
# ----> 4 ax.plot(x, actuals_nash, label='Myopic', interpolate=True)
#       5 ax.plot(x, bests_nash, '--', label='Global')
#       6 x_ticks = [(a + 1)/100 for a in range(99)]
#
# File ~\anaconda3\envs\cvrp\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# File ~\anaconda3\envs\cvrp\lib\site-packages\matplotlib\axes\_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File ~\anaconda3\envs\cvrp\lib\site-packages\matplotlib\axes\_base.py:538, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     536     return list(result)
#     537 else:
# --> 538     return [l[0] for l in result]
#
# File ~\anaconda3\envs\cvrp\lib\site-packages\matplotlib\axes\_base.py:538, in <listcomp>(.0)
#     536     return list(result)
#     537 else:
# --> 538     return [l[0] for l in result]
#
# File ~\anaconda3\envs\cvrp\lib\site-packages\matplotlib\axes\_base.py:531, in <genexpr>(.0)
#     528 else:
#     529     labels = [label] * n_datasets
# --> 531 result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     532                       {**kwargs, 'label': label})
#     533           for j, label in enumerate(labels))
#     535 if return_kwargs:
#     536     return list(result)
#
# File ~\anaconda3\envs\cvrp\lib\site-packages\matplotlib\axes\_base.py:351, in _process_plot_var_args._makeline(self, x, y, kw, kwargs)
#     349 default_dict = self._getdefaults(set(), kw)
#     350 self._setdefaults(default_dict, kw)
# --> 351 seg = mlines.Line2D(x, y, **kw)
#     352 return seg, kw
#
# File ~\anaconda3\envs\cvrp\lib\site-packages\matplotlib\lines.py:393, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     389 self.set_markeredgewidth(markeredgewidth)
#     391 # update kwargs before updating data to give the caller a
#     392 # chance to init axes (and hence unit support)
# --> 393 self.update(kwargs)
#     394 self.pickradius = pickradius
#     395 self.ind_offset = 0
#
# File ~\anaconda3\envs\cvrp\lib\site-packages\matplotlib\artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'Line2D' object has no property 'interpolate'

# %%
opt = 0
actuals_elite = []
bests_elite = []

swf = reward_eite
for g in range(98):
    g = (g + 1)/100
    best_value = [g**(k) for k in range(6)]
    best_value.append(100*g**6)
    best_value = sum(best_value)
    best = swf([best_value, best_value])

    values, best_actions = value_iteration(14, 4, get_loc, get_reward, moves1, t1=[3], t2=[1], gamma=g, swf=swf)
    terminal, num_steps, r1, r2 = get_path(best_actions, get_loc, moves1, 7, 11, [3], [1], g)
    actual1 = sum(r1)
    actual2 = sum(r2)
    actual = swf([actual1, actual2])
    strategy = 1
    if terminal == (3, 1):
        strategy = 2

    best = max(actual, best)
    actuals_elite.append(actual)
    bests_elite.append(best)

    print(f'I am running strategy {strategy} for {g} with value {values[(7, 11)]}, {actual - best}')


fig = plt.figure()
x = np.arange(.01, .99, .01)
ax = fig.add_subplot()
ax.plot(x, actuals_elite, label='Myopic')
ax.plot(x, bests_elite, label='Global')
x_ticks = [(a + 1)/100 for a in range(99)]
x = range(99)
plt.xlabel('gamma')
plt.ylabel('Social Welfare')
# [l.set_visible(False) for (i,l) in enumerate(plt.xaxis.get_ticklabels()) if i % 10 != 0]

plt.legend()
fig.show()
# Out:
# I am running strategy 1 for 0.01 with value 1.010102, 0.0
# I am running strategy 1 for 0.02 with value 1.020424, 0.0
# I am running strategy 1 for 0.03 with value 1.031008, 0.0
# I am running strategy 1 for 0.04 with value 1.04192, 0.0
# I am running strategy 1 for 0.05 with value 1.05325, 0.0
# I am running strategy 1 for 0.06 with value 1.065112, 0.0
# I am running strategy 1 for 0.07 with value 1.077644, 0.0
# I am running strategy 1 for 0.08 with value 1.091008, 0.0
# I am running strategy 1 for 0.09 with value 1.10539, 0.0
# I am running strategy 1 for 0.1 with value 1.121, 0.0
# I am running strategy 1 for 0.11 with value 1.138072, 0.0
# I am running strategy 1 for 0.12 with value 1.156864, 0.0
# I am running strategy 1 for 0.13 with value 1.177658, 0.0
# I am running strategy 1 for 0.65 with value 20.19775, 0.0
# I am running strategy 1 for 0.66 with value 21.357832000000002, 0.0
# I am running strategy 1 for 0.67 with value 22.570784, 0.0
# I am running strategy 1 for 0.68 with value 23.838208000000005, 0.0
# I am running strategy 1 for 0.69 with value 25.161729999999995, 0.0
# I am running strategy 1 for 0.7 with value 26.542999999999996, 0.0
# I am running strategy 1 for 0.71 with value 27.983691999999994, 0.0
# I am running strategy 1 for 0.72 with value 29.485503999999995, 0.0
# I am running strategy 1 for 0.73 with value 31.050157999999993, 0.0
# I am running strategy 1 for 0.74 with value 32.6794, 0.0
# I am running strategy 1 for 0.75 with value 34.375, 0.0
# I am running strategy 1 for 0.76 with value 36.138752000000004, 0.0
# I am running strategy 1 for 0.77 with value 37.972474000000005, 0.0
# I am running strategy 1 for 0.78 with value 39.878008, 0.0
# I am running strategy 1 for 0.79 with value 41.857220000000005, 0.0
# I am running strategy 1 for 0.8 with value 43.912000000000006, 0.0
# I am running strategy 1 for 0.81 with value 46.04426200000001, 0.0
# I am running strategy 1 for 0.82 with value 48.25594399999999, 0.0
# I am running strategy 1 for 0.83 with value 50.54900799999999, 0.0
# I am running strategy 1 for 0.84 with value 52.92543999999999, 0.0
# I am running strategy 1 for 0.85 with value 55.387249999999995, 0.0
# I am running strategy 1 for 0.86 with value 57.93647199999999, 0.0
# I am running strategy 1 for 0.87 with value 60.575163999999994, 0.0
# I am running strategy 1 for 0.88 with value 63.30540800000001, 0.0
# I am running strategy 1 for 0.89 with value 66.12931, 0.0
# I am running strategy 1 for 0.9 with value 69.04900000000002, 0.0
# I am running strategy 1 for 0.91 with value 72.06663200000001, 0.0
# I am running strategy 1 for 0.92 with value 75.18438400000001, 0.0
# I am running strategy 1 for 0.93 with value 78.40445800000002, 0.0
# I am running strategy 1 for 0.94 with value 81.72907999999998, 0.0
# I am running strategy 1 for 0.95 with value 85.16049999999998, 0.0
# I am running strategy 1 for 0.96 with value 88.70099199999999, 0.0
# I am running strategy 1 for 0.97 with value 92.35285400000001, 0.0
# I am running strategy 1 for 0.98 with value 96.11840799999999, 0.0
# C:\Users\Chris\AppData\Local\Temp\ipykernel_40628\2642702873.py:41: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
opt = 0
actuals_egal = []
bests_egal = []

swf = reward_egal
for g in range(98):
    g = (g + 1)/100
    best_value = [g**(k) for k in range(6)]
    best_value.append(100*g**6)
    best_value = sum(best_value)
    best = swf([best_value, best_value])

    values, best_actions = value_iteration(14, 4, get_loc, get_reward, moves1, t1=[3], t2=[1], gamma=g, swf=swf)
    terminal, num_steps, r1, r2 = get_path(best_actions, get_loc, moves1, 7, 11, [3], [1], g)
    actual1 = sum(r1)
    actual2 = sum(r2)
    actual = swf([actual1, actual2])
    strategy = 1
    if terminal == (3, 1):
        strategy = 2

    best = max(actual, best)
    actuals_egal.append(actual)
    bests_egal.append(best)

    print(f'I am running strategy {strategy} for {g} with value {values[(7, 11)]}, {actual - best}')


fig = plt.figure()
x = np.arange(.01, .99, .01)
ax = fig.add_subplot()
ax.plot(x, actuals_egal, label='Myopic')
ax.plot(x, bests_egal, label='Global')
x_ticks = [(a + 1)/100 for a in range(99)]
x = range(99)
plt.xlabel('gamma')
plt.ylabel('Social Welfare')
# ax.set_xticks(np.arange(0, 100, 5))
# [l.set_visible(False) for (i,l) in enumerate(plt.xaxis.get_ticklabels()) if i % 10 != 0]

plt.legend()
fig.show()
# Out:
# I am running strategy 2 for 0.01 with value 1.0101010101010102, -9.89799353590115e-11
# I am running strategy 2 for 0.02 with value 1.0204081696, 0.0
# I am running strategy 2 for 0.03 with value 1.0309279072, 0.0
# I am running strategy 2 for 0.04 with value 1.041667072, 0.0
# I am running strategy 2 for 0.05 with value 1.052633125, 0.0
# I am running strategy 2 for 0.06 with value 1.0638344032, 0.0
# I am running strategy 2 for 0.07 with value 1.0752804556, 0.0
# I am running strategy 2 for 0.08 with value 1.0869824512, 0.0
# I am running strategy 2 for 0.09 with value 1.098953659, 0.0
# I am running strategy 2 for 0.1 with value 1.11121, 0.0
# I am running strategy 2 for 0.11 with value 1.1237706712, 0.0
# I am running strategy 2 for 0.12 with value 1.1366588416, 0.0
# I am running strategy 2 for 0.13 with value 1.1499024202, 0.0
# I am running strategy 2 for 0.14 with value 1.163534896, 0.0
# I am running strategy 2 for 0.15 with value 1.17759625, 0.0
# I am running strategy 2 for 0.16 with value 1.1921339392, 0.0
# I am running strategy 2 for 0.17 with value 1.2072039526, 0.0
# I am running strategy 2 for 0.18 with value 1.2228719392, 0.0
# I am running strategy 2 for 0.19 with value 1.239214408, 0.0
# I am running strategy 2 for 0.2 with value 1.25632, 0.0
# I am running strategy 2 for 0.21 with value 1.2742908322, 0.0
# I am running strategy 2 for 0.22 with value 1.2932439136, 0.0
# I am running strategy 2 for 0.23 with value 1.3133126332, 0.0
# I am running strategy 2 for 0.24 with value 1.3346483199999999, 0.0
# I am running strategy 2 for 0.25 with value 1.357421875, 0.0
# I am running strategy 2 for 0.26 with value 1.3818254751999999, 0.0
# I am running strategy 2 for 0.27 with value 1.4080743496, 0.0
# I am running strategy 2 for 0.28 with value 1.4364086272, 0.0
# I am running strategy 2 for 0.29 with value 1.467095257, 0.0
# I am running strategy 2 for 0.3 with value 1.50043, 0.0
# I am running strategy 2 for 0.31 with value 1.5367394932, 0.0
# I am running strategy 2 for 0.32 with value 1.5763833856, 0.0
# I am running strategy 2 for 0.33 with value 1.6197565462, 0.0
# I am running strategy 2 for 0.34 with value 1.6672913440000001, 0.0
# I am running strategy 2 for 0.35 with value 1.71946, 0.0
# I am running strategy 2 for 0.36 with value 1.7767770112, 0.0
# I am running strategy 2 for 0.37 with value 1.8398016466, 0.0
# I am running strategy 2 for 0.38 with value 1.9091405151999998, 0.0
# I am running strategy 2 for 0.39 with value 1.985450206, 0.0
# I am running strategy 2 for 0.4 with value 2.06944, 0.0
# I am running strategy 2 for 0.41 with value 2.1618746541999996, 0.0
# I am running strategy 2 for 0.42 with value 2.2635772575999997, 0.0
# I am running strategy 2 for 0.43 with value 2.3754321592, 0.0
# I am running strategy 2 for 0.44 with value 2.4983879680000003, 0.0
# I am running strategy 2 for 0.93 with value 69.74201572420003, 0.0
# I am running strategy 2 for 0.94 with value 74.15581508799998, 0.0
# I am running strategy 2 for 0.95 with value 78.80735124999998, 0.0
# I am running strategy 2 for 0.96 with value 83.70683422719998, 0.0
# I am running strategy 2 for 0.97 with value 88.8648003286, 0.0
# I am running strategy 2 for 0.98 with value 94.29211904319999, 0.0
# C:\Users\Chris\AppData\Local\Temp\ipykernel_40628\3675475375.py:42: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
opt = 0
actuals_util = []
bests_util = []

swf = reward_util
for g in range(98):
    g = (g + 1)/100
    best_value = [g**(k) for k in range(6)]
    best_value.append(100*g**6)
    best_value = sum(best_value)
    best = swf([best_value, best_value])

    values, best_actions = value_iteration(14, 4, get_loc, get_reward, moves1, t1=[3], t2=[1], gamma=g, swf=swf)
    terminal, num_steps, r1, r2 = get_path(best_actions, get_loc, moves1, 7, 11, [3], [1], g)
    actual1 = sum(r1)
    actual2 = sum(r2)
    actual = swf([actual1, actual2])
    strategy = 1
    if terminal == (3, 1):
        strategy = 2

    best = max(actual, best)
    actuals_util.append(actual)
    bests_util.append(best)

    print(f'I am running strategy {strategy} for {g} with value {values[(7, 11)]}, {actual - best}')


fig = plt.figure()
ax = fig.add_subplot()
ax.plot(actuals_util, label='Myopic')
ax.plot(bests_util, label='Global')
x_ticks = [(a + 1)/100 for a in range(99)]
x = range(99)
plt.xlabel('gamma *10^2')
plt.ylabel('Social Welfare')
ax.set_xticks(np.arange(0, 100, 5))
# [l.set_visible(False) for (i,l) in enumerate(plt.xaxis.get_ticklabels()) if i % 10 != 0]

plt.legend()
fig.show()
# Out:
# I am running strategy 1 for 0.01 with value 2.02020301, 0.0
# I am running strategy 1 for 0.02 with value 2.04083216, 0.0
# I am running strategy 1 for 0.03 with value 2.06193581, 0.0
# I am running strategy 1 for 0.04 with value 2.08358656, 0.0
# I am running strategy 1 for 0.05 with value 2.10588125, 0.0
# I am running strategy 1 for 0.06 with value 2.12894096, 0.0
# I am running strategy 1 for 0.07 with value 2.15291101, 0.0
# I am running strategy 1 for 0.08 with value 2.17796096, 0.0
# I am running strategy 1 for 0.09 with value 2.20428461, 0.0
# I am running strategy 1 for 0.1 with value 2.2321, 0.0
# I am running strategy 1 for 0.11 with value 2.26164941, 0.0
# I am running strategy 1 for 0.12 with value 2.29319936, 0.0
# I am running strategy 1 for 0.13 with value 2.32704061, 0.0
# I am running strategy 1 for 0.14 with value 2.36348816, 0.0
# I am running strategy 1 for 0.15 with value 2.40288125, 0.0
# I am running strategy 1 for 0.16 with value 2.44558336, 0.0
# I am running strategy 1 for 0.17 with value 2.49198221, 0.0
# I am running strategy 1 for 0.18 with value 2.54248976, 0.0
# I am running strategy 1 for 0.19 with value 2.5975422100000003, 0.0
# I am running strategy 1 for 0.2 with value 2.6576, 0.0
# I am running strategy 1 for 0.21 with value 2.72314781, 0.0
# I am running strategy 1 for 0.22 with value 2.79469456, 0.0
# I am running strategy 1 for 0.23 with value 2.87277341, 0.0
# I am running strategy 1 for 0.24 with value 2.9579417599999998, 0.0
# I am running strategy 1 for 0.25 with value 3.05078125, 0.0
# I am running strategy 2 for 0.75 with value 42.171875, 0.0
# I am running strategy 2 for 0.76 with value 45.2674863104, 0.0
# I am running strategy 2 for 0.77 with value 48.56775966920001, 0.0
# I am running strategy 2 for 0.78 with value 52.0835601344, 0.0
# I am running strategy 2 for 0.79 with value 55.82618200400002, 0.0
# I am running strategy 2 for 0.8 with value 59.80736000000001, 0.0
# I am running strategy 2 for 0.81 with value 64.03928059640002, 0.0
# I am running strategy 2 for 0.82 with value 68.53459349119998, 0.0
# I am running strategy 2 for 0.83 with value 73.30642322239999, 0.0
# I am running strategy 2 for 0.84 with value 78.36838092799998, 0.0
# I am running strategy 2 for 0.85 with value 83.73457624999999, 0.0
# I am running strategy 2 for 0.86 with value 89.41962938239998, 0.0
# I am running strategy 2 for 0.87 with value 95.43868326319999, 0.0
# I am running strategy 2 for 0.88 with value 101.80741591040001, 0.0
# I am running strategy 2 for 0.89 with value 108.54205290200001, 0.0
# I am running strategy 2 for 0.9 with value 115.65938000000004, 0.0
# I am running strategy 2 for 0.91 with value 123.17675591840002, 0.0
# I am running strategy 2 for 0.92 with value 131.11212523520004, 0.0
# I am running strategy 2 for 0.93 with value 139.48403144840006, 0.0
# I am running strategy 2 for 0.94 with value 148.31163017599997, 0.0
# I am running strategy 2 for 0.95 with value 157.61470249999996, 0.0
# I am running strategy 2 for 0.96 with value 167.41366845439995, 0.0
# I am running strategy 2 for 0.97 with value 177.7296006572, 0.0
# I am running strategy 2 for 0.98 with value 188.58423808639998, 0.0
# C:\Users\Chris\AppData\Local\Temp\ipykernel_40628\3840075275.py:41: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import FormatStrFormatter

fig,axs = plt.subplots(2, 2, constrained_layout=True)
ax1 = axs[0, 0]
ax2 = axs[0, 1]
ax3 = axs[1, 0]
ax4 = axs[1, 1]
# fig.tight_layout()

x = np.arange(.01, .99, .01)
#ax1 = fig.add_subplot()
ax1.plot(x, actuals_nash, label='Myopic')
ax1.plot(x, bests_nash, '--', label='Global')
ax1.set_title('Nash Social Welfare')
# ax1.set_xlabel('gamma')
ax1.set_ylabel('Log Social Welfare')
ax1.legend()


ax2.plot(x, actuals_util, label='Myopic')
ax2.plot(x, bests_util, '--', label='Global')
ax2.set_title('Utilitarian Social Welfare')
# ax2.set_xlabel('gamma')
ax2.set_ylabel('Social Welfare')
ax2.legend()

ax3.plot(x, actuals_egal, label='Myopic')
ax3.plot(x, bests_egal, '--', label='Global')
ax3.set_title('Egalitarian Social Welfare')
ax3.set_xlabel('gamma')
ax3.set_ylabel('Social Welfare')
ax3.legend()

ax4.plot(x, actuals_elite, label='Myopic')
ax4.plot(x, bests_elite, '--', label='Global')
ax4.set_title('Elitist Social Welfare')
ax4.set_xlabel('gamma')
ax4.set_ylabel('Social Welfare')
ax4.legend()

# ax.set_xticks(np.arange(0, 100, 5))
# [l.set_visible(False) for (i,l) in enumerate(plt.xaxis.get_ticklabels()) if i % 10 != 0]

# %%
fig.savefig('experiments_take_two.png')
